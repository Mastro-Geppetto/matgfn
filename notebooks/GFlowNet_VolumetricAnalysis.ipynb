# %% [markdown]
# # Material Science repo
# This is a demo notebook for "Discovery of Reticular Materials​  for Carbon Dioxide Capture​ Using GFlowNets​"
#
# https://arxiv.org/abs/2310.07671
#
# https://github.com/Mastro-Geppetto/matgfn

# %% [markdown]
# # Setup matgfn

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
# !git clone https://github.com/Mastro-Geppetto/matgfn.git
# Out:
# Cloning into 'matgfn'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (240/240), done.
# remote: Total 251 (delta 8), reused 235 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (251/251), 24.74 MiB | 14.89 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !pip install -e matgfn
# Out:
# Obtaining file:///content/matgfn
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting torch==2.1.0 (from matgfn==0.1)
#   Downloading torch-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting nglview==3.0.8 (from matgfn==0.1)
#   Downloading nglview-3.0.8.tar.gz (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 16.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tqdm==4.66.1 (from matgfn==0.1)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.1 MB/s eta 0:00:00
# Collecting gymnasium==0.29.1 (from matgfn==0.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Collecting numpy==1.26.0 (from matgfn==0.1)
#   Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 6.0 MB/s eta 0:00:00
# Collecting matplotlib==3.8.0 (from matgfn==0.1)
#   Downloading matplotlib-3.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting pymatgen==2023.10.4 (from matgfn==0.1)
#   Downloading pymatgen-2023.10.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting pormake==0.1.2 (from matgfn==0.1)
#   Downloading pormake-0.1.2-py3-none-any.whl.metadata (14 kB)
# Collecting scikit-learn==1.3.2 (from matgfn==0.1)
#   Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->matgfn==0.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->matgfn==0.1) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->matgfn==0.1) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.8.0->matgfn==0.1) (2.9.0.post0)
# Requirement already satisfied: ipywidgets>=7 in /usr/local/lib/python3.11/dist-packages (from nglview==3.0.8->matgfn==0.1) (7.7.1)
# Requirement already satisfied: jupyterlab_widgets in /usr/local/lib/python3.11/dist-packages (from nglview==3.0.8->matgfn==0.1) (3.0.14)
# Collecting ase<4.0.0,>=3.22.1 (from pormake==0.1.2->matgfn==0.1)
#   Downloading ase-3.25.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting jax<0.5.0,>=0.4.1 (from jax[cpu]<0.5.0,>=0.4.1->pormake==0.1.2->matgfn==0.1)
#   Downloading jax-0.4.38-py3-none-any.whl.metadata (22 kB)
# Collecting monty>=3.0.2 (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (3.4.2)
# Collecting palettable>=3.1.1 (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (2.2.2)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (5.24.1)
# Collecting pybtex (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (2.32.3)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (1.15.2)
# Collecting spglib>=2.0.2 (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (1.13.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (0.9.0)
# Collecting uncertainties>=3.1.4 (from pymatgen==2023.10.4->matgfn==0.1)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from pymatgen==2023.10.4->matgfn==0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->matgfn==0.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0->matgfn==0.1) (3.18.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0->matgfn==0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.1.0->matgfn==0.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.0->matgfn==0.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.1.0 (from torch==2.1.0->matgfn==0.1)
#   Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->matgfn==0.1) (12.5.82)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (7.34.0)
# Collecting jaxlib<=0.4.38,>=0.4.38 (from jax<0.5.0,>=0.4.1->jax[cpu]<0.5.0,>=0.4.1->pormake==0.1.2->matgfn==0.1)
#   Downloading jaxlib-0.4.38-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax<0.5.0,>=0.4.1->jax[cpu]<0.5.0,>=0.4.1->pormake==0.1.2->matgfn==0.1) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax<0.5.0,>=0.4.1->jax[cpu]<0.5.0,>=0.4.1->pormake==0.1.2->matgfn==0.1) (3.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.5.0->pymatgen==2023.10.4->matgfn==0.1) (9.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib==3.8.0->matgfn==0.1) (1.17.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen==2023.10.4->matgfn==0.1)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.1.0->matgfn==0.1) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pymatgen==2023.10.4->matgfn==0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pymatgen==2023.10.4->matgfn==0.1) (2025.2)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.11/dist-packages (from pybtex->pymatgen==2023.10.4->matgfn==0.1) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex->pymatgen==2023.10.4->matgfn==0.1)
#   Downloading latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2023.10.4->matgfn==0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2023.10.4->matgfn==0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2023.10.4->matgfn==0.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2023.10.4->matgfn==0.1) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->pymatgen==2023.10.4->matgfn==0.1) (1.3.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (5.7.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7->nglview==3.0.8->matgfn==0.1) (1.3.1)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 51.5 MB/s eta 0:00:00
# Downloading matplotlib-3.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 109.2 MB/s eta 0:00:00
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 83.4 MB/s eta 0:00:00
# Downloading pormake-0.1.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.5 MB/s eta 0:00:00
# Downloading pymatgen-2023.10.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 15.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 116.9 MB/s eta 0:00:00
# Downloading torch-2.1.0-cp311-cp311-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.8 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 102.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 92.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.6 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 7.8 MB/s eta 0:00:00
# Downloading ase-3.25.0-py3-none-any.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 71.2 MB/s eta 0:00:00
# Downloading jax-0.4.38-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 63.8 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 5.5 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 32.6 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 13.5 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 57.0 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 7.1 MB/s eta 0:00:00
# Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 46.8 MB/s eta 0:00:00
# Downloading jaxlib-0.4.38-cp311-cp311-manylinux2014_x86_64.whl (101.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 MB 8.3 MB/s eta 0:00:00
# Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 54.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.4 MB/s eta 0:00:00
# Building wheels for collected packages: matgfn, nglview
#   Building editable for matgfn (pyproject.toml) ... done
#   Created wheel for matgfn: filename=matgfn-0.1-0.editable-py3-none-any.whl size=3254 sha256=a1037c1f17dc9fd9868deaefa53e5e1ba670bc4e2aad6a0ca4a1ba832d604650
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dulri73u/wheels/42/ca/96/4ef7effc6343338bbd7c1742cb41079aac03bba841a4f3f3d1
#   Building wheel for nglview (pyproject.toml) ... done
#   Created wheel for nglview: filename=nglview-3.0.8-py3-none-any.whl size=10216245 sha256=c52cd6a7cfd36d290c5c956323f134176f25abb9c47dcfd00c7f2cdbdd6d37a9
#   Stored in directory: /root/.cache/pip/wheels/e8/20/cc/77f7e31d85bb77ce0fe339e7f89d52dff29a942593886e35de
# Successfully built matgfn nglview
# Installing collected packages: uncertainties, triton, tqdm, ruamel.yaml.clib, palettable, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, latexcodec, jedi, spglib, ruamel.yaml, pybtex, nvidia-cusolver-cu12, nvidia-cudnn-cu12, gymnasium, torch, scikit-learn, monty, matplotlib, jaxlib, pymatgen, jax, ase, pormake, nglview, matgfn
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.5.1
#     Uninstalling jaxlib-0.5.1:
#       Successfully uninstalled jaxlib-0.5.1
#   Attempting uninstall: jax
#     Found existing installation: jax 0.5.2
#     Uninstalling jax-0.5.2:
#       Successfully uninstalled jax-0.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.0 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.1.0 which is incompatible.
# flax 0.10.6 requires jax>=0.5.1, but you have jax 0.4.38 which is incompatible.
# dataproc-spark-connect 0.7.2 requires tqdm>=4.67, but you have tqdm 4.66.1 which is incompatible.
# orbax-checkpoint 0.11.13 requires jax>=0.5.0, but you have jax 0.4.38 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.1.0 which is incompatible.
# Successfully installed ase-3.25.0 gymnasium-0.29.1 jax-0.4.38 jaxlib-0.4.38 jedi-0.19.2 latexcodec-3.0.0 matgfn-0.1 matplotlib-3.8.0 monty-2025.3.3 nglview-3.0.8 numpy-1.26.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvtx-cu12-12.1.105 palettable-3.3.3 pormake-0.1.2 pybtex-0.24.0 pymatgen-2023.10.4 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 scikit-learn-1.3.2 spglib-2.6.0 torch-2.1.0 tqdm-4.66.1 triton-2.1.0 uncertainties-3.2.3

# %% [markdown]
# ### restart runtime for setup to continue

# %%
import matplotlib,mpl_toolkits

# %%
import torch

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
import matgfn

# %% [markdown]
# ## Validate libs can be imported without errors

# %%
# GFlowNet
from matgfn.gflow.environments.sequence import SequenceEnvironment
from matgfn.gflow.agent import TrajectoryBalanceGFlowNet
from matgfn.gflow.flow_models.lstm import LSTM

# MOF
from matgfn.reticular import PormakeStructureBuilder
import nglview as nv

# Utils
from tqdm import tqdm
import math
import subprocess
import os
import tempfile

# %% [markdown]
# ### add Jypter enable custom widget manager for pymatgen

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ## python lib : PormakeStructureBuilder : We can make random MOF using Pormake.
# `PormakeStructureBuilder` is our class. It hides pormake instance.
#
# `PormakerStructureBuilder` uses `MOFMask` which holds data about topology (num of node edge etc).

# %%
builder = PormakeStructureBuilder(topology_string="ffc", include_edges=True, block_rmsd_cutoff=0.1)
cutoff = 5000
print(f"Number of potential materials with allowed building blocks for \"FFC\" topology: {math.prod([len(x) for x in builder.mask.forward_actions_at_each_slot]):,}")
# Out:
# /usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# Number of potential materials with allowed building blocks: 12,789,603,200

# %% [markdown]
# ### python lib : Pymatgen demo : Visualize a random structure using Pymatgen

# %%
# Make a random material
sequence = builder.random_sequence()
structure =  builder.make_structure(sequence)

# Visualise it with Pymatgen
nv.show_pymatgen(structure)
# Out:
# /usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# NGLWidget()

# %% [markdown]
# ## external lib installation : zeo++
# zeo++ is an open source software for performing high-throughput geometry-based analysis of porous materials and their voids.
#
# https://www.zeoplusplus.org/about.html

# %%
# !wget http://www.zeoplusplus.org/zeo++-0.3.tar.gz
# Out:
# --2025-05-11 10:02:44--  http://www.zeoplusplus.org/zeo++-0.3.tar.gz
# Resolving www.zeoplusplus.org (www.zeoplusplus.org)... 204.44.192.67
# Connecting to www.zeoplusplus.org (www.zeoplusplus.org)|204.44.192.67|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4831470 (4.6M) [application/x-gzip]
# Saving to: ‘zeo++-0.3.tar.gz’
#
# zeo++-0.3.tar.gz    100%[===================>]   4.61M  --.-KB/s    in 0.08s
#
# 2025-05-11 10:02:45 (56.2 MB/s) - ‘zeo++-0.3.tar.gz’ saved [4831470/4831470]

# %% [markdown]
# ### Extract and make

# %%
# !tar -xzvf zeo++-0.3.tar.gz
# Out:
# zeo++-0.3/
# zeo++-0.3/channel.h
# zeo++-0.3/networkstorage.h
# zeo++-0.3/cycle.cc
# zeo++-0.3/networkaccessibility.h
# zeo++-0.3/poreinfo.cc
# zeo++-0.3/general.h
# zeo++-0.3/Makefile.dep
# zeo++-0.3/networkinfo.cc
# zeo++-0.3/sphere_approx.cc
# zeo++-0.3/tdpldhistogram.cc
# zeo++-0.3/arguments.h
# zeo++-0.3/geometry.h
# zeo++-0.3/wget.csh
# zeo++-0.3/string_additions.cc
# zeo++-0.3/octree.hpp
# zeo++-0.3/voronoicell.h
# zeo++-0.3/instructions.cc
# zeo++-0.3/symmetry.h
# zeo++-0.3/segment.h
# zeo++-0.3/heap.h
# zeo++-0.3/poreinfo.h
# zeo++-0.3/ray.cc
# zeo++-0.3/symbcalc.h
# zeo++-0.3/molecule_to_abstract.cc
# zeo++-0.3/Makefile
# zeo++-0.3/arguments.cc
# zeo++-0.3/holograms.cc
# zeo++-0.3/Docs/
# zeo++-0.3/Docs/Zeo_tutorial_word.ppt
# zeo++-0.3/Docs/Visualizing_pore_size_distribution_files_in_VisIt.ppt
# zeo++-0.3/networkio.cc
# zeo++-0.3/graphstorage.cc
# zeo++-0.3/builder_examples/
# zeo++-0.3/builder_examples/building_blocks/
# zeo++-0.3/builder_examples/building_blocks/trigonal.xyz
# zeo++-0.3/builder_examples/building_blocks/pyr_linker_without_sites.xyz
# zeo++-0.3/builder_examples/building_blocks/molecule3.xyz
# zeo++-0.3/builder_examples/building_blocks/qom_linker_without_sites.xyz
# zeo++-0.3/builder_examples/building_blocks/molecule_without_sites.xyz
# zeo++-0.3/builder_examples/building_blocks/linear.xyz
# zeo++-0.3/builder_examples/building_blocks/Cu2.xyz
# zeo++-0.3/builder_examples/building_blocks/tetrahedral.xyz
# zeo++-0.3/builder_examples/building_blocks/Zn4O.xyz
# zeo++-0.3/builder_examples/building_blocks/C.xyz
# zeo++-0.3/builder_examples/building_blocks/moleculeC.xyz
# zeo++-0.3/builder_examples/building_blocks/linear_nonsym_without_sites.xyz
# zeo++-0.3/builder_examples/nets/
# zeo++-0.3/builder_examples/nets/hcb.cgd
# zeo++-0.3/builder_examples/nets/pts.cgd
# zeo++-0.3/builder_examples/nets/dia-c5.cgd
# zeo++-0.3/builder_examples/nets/tbo.cgd
# zeo++-0.3/builder_examples/nets/pyr.cgd
# zeo++-0.3/builder_examples/nets/rhr.cgd
# zeo++-0.3/builder_examples/nets/ntt_simple.cgd
# zeo++-0.3/builder_examples/nets/dia.cgd
# zeo++-0.3/builder_examples/nets/qom.cgd
# zeo++-0.3/LICENSE
# zeo++-0.3/feature.h
# zeo++-0.3/string_additions.h
# zeo++-0.3/area_and_volume.cc
# zeo++-0.3/networkanalysis.cc
# zeo++-0.3/grid.cc
# zeo++-0.3/channel.cc
# zeo++-0.3/cycle.h
# zeo++-0.3/mindist.h
# zeo++-0.3/zeo_consts.h
# zeo++-0.3/feature.cc
# zeo++-0.3/OVERVIEW.txt
# zeo++-0.3/rmsd.h
# zeo++-0.3/zeojobs.h
# zeo++-0.3/OMS.h
# zeo++-0.3/segment.cc
# zeo++-0.3/instructions.h
# zeo++-0.3/psd.h
# zeo++-0.3/network.cc
# zeo++-0.3/zeovis/
# zeo++-0.3/zeovis/ZeoVisCommands.tcl
# zeo++-0.3/zeovis/ZeoVis.tcl
# zeo++-0.3/zeovis/README
# zeo++-0.3/get_holo_similarity.c
# zeo++-0.3/default_bin_bounds.tar
# zeo++-0.3/CHECKLIST_B4_RELEASE.txt
# zeo++-0.3/symbcalc.cc
# zeo++-0.3/ray.h
# zeo++-0.3/config.mk
# zeo++-0.3/sphere_approx.h
# zeo++-0.3/network.h
# zeo++-0.3/networkinfo.h
# zeo++-0.3/HELP.txt
# zeo++-0.3/net.h
# zeo++-0.3/material.cc
# zeo++-0.3/voronoicell.cc
# zeo++-0.3/holo_similarity.h
# zeo++-0.3/v_network.h
# zeo++-0.3/cython_wrapper/
# zeo++-0.3/cython_wrapper/setup_alt.py
# zeo++-0.3/cython_wrapper/zeo/
# zeo++-0.3/cython_wrapper/zeo/string_add.pxd
# zeo++-0.3/cython_wrapper/zeo/voronoicell.pyx
# zeo++-0.3/cython_wrapper/zeo/feature.pxd
# zeo++-0.3/cython_wrapper/zeo/area_volume.pxd
# zeo++-0.3/cython_wrapper/zeo/channel.pxd
# zeo++-0.3/cython_wrapper/zeo/area_volume.pyx
# zeo++-0.3/cython_wrapper/zeo/graphstorage.pyx
# zeo++-0.3/cython_wrapper/zeo/high_accuracy.pxd
# zeo++-0.3/cython_wrapper/zeo/netinfo.pyx
# zeo++-0.3/cython_wrapper/zeo/geometry.cpp
# zeo++-0.3/cython_wrapper/zeo/netinfo.cpp
# zeo++-0.3/cython_wrapper/zeo/holograms.pyx
# zeo++-0.3/cython_wrapper/zeo/netstorage.cpp
# zeo++-0.3/cython_wrapper/zeo/geometry.pxd
# zeo++-0.3/cython_wrapper/zeo/graphstorage.cpp
# zeo++-0.3/cython_wrapper/zeo/netstorage.pyx
# zeo++-0.3/cython_wrapper/zeo/channel.pyx
# zeo++-0.3/cython_wrapper/zeo/cycle.pyx
# zeo++-0.3/cython_wrapper/zeo/high_accuracy.cpp
# zeo++-0.3/cython_wrapper/zeo/cluster.pxd
# zeo++-0.3/cython_wrapper/zeo/voronoicell.pxd
# zeo++-0.3/cython_wrapper/zeo/holograms.pxd
# zeo++-0.3/cython_wrapper/zeo/cluster.cpp
# zeo++-0.3/cython_wrapper/zeo/channel.cpp
# zeo++-0.3/cython_wrapper/zeo/psd.pyx
# zeo++-0.3/cython_wrapper/zeo/cluster.pyx
# zeo++-0.3/cython_wrapper/zeo/netinfo.pxd
# zeo++-0.3/cython_wrapper/zeo/netio.pxd
# zeo++-0.3/cython_wrapper/zeo/area_volume.cpp
# zeo++-0.3/cython_wrapper/zeo/tests/
# zeo++-0.3/cython_wrapper/zeo/tests/MgO.cssr
# zeo++-0.3/cython_wrapper/zeo/tests/test_highaccuracy.py
# zeo++-0.3/cython_wrapper/zeo/tests/MgO.rad
# zeo++-0.3/cython_wrapper/zeo/tests/test_areavol.py
# zeo++-0.3/cython_wrapper/zeo/tests/test_cycle.py
# zeo++-0.3/cython_wrapper/zeo/tests/test_cluster.py
# zeo++-0.3/cython_wrapper/zeo/tests/MgO_vac1.cssr
# zeo++-0.3/cython_wrapper/zeo/tests/test_netstorage.py
# zeo++-0.3/cython_wrapper/zeo/netio.pyx
# zeo++-0.3/cython_wrapper/zeo/voronoicell.cpp
# zeo++-0.3/cython_wrapper/zeo/geometry.pyx
# zeo++-0.3/cython_wrapper/zeo/__init__.py
# zeo++-0.3/cython_wrapper/zeo/psd.cpp
# zeo++-0.3/cython_wrapper/zeo/netstorage.pxd
# zeo++-0.3/cython_wrapper/zeo/graphstorage.pxd
# zeo++-0.3/cython_wrapper/zeo/network.pxd
# zeo++-0.3/cython_wrapper/zeo/cycle.cpp
# zeo++-0.3/cython_wrapper/zeo/netio.cpp
# zeo++-0.3/cython_wrapper/zeo/cycle.pxd
# zeo++-0.3/cython_wrapper/zeo/psd.pxd
# zeo++-0.3/cython_wrapper/zeo/high_accuracy.pyx
# zeo++-0.3/cython_wrapper/setup.py
# zeo++-0.3/gpu_energy.h
# zeo++-0.3/framework_builder.cc
# zeo++-0.3/Eigen/
# zeo++-0.3/Eigen/Sparse
# zeo++-0.3/Eigen/MetisSupport
# zeo++-0.3/Eigen/UmfPackSupport
# zeo++-0.3/Eigen/Eigen2Support
# zeo++-0.3/Eigen/SuperLUSupport
# zeo++-0.3/Eigen/CholmodSupport
# zeo++-0.3/Eigen/SparseCore
# zeo++-0.3/Eigen/LeastSquares
# zeo++-0.3/Eigen/Core
# zeo++-0.3/Eigen/QtAlignedMalloc
# zeo++-0.3/Eigen/Cholesky
# zeo++-0.3/Eigen/Jacobi
# zeo++-0.3/Eigen/IterativeLinearSolvers
# zeo++-0.3/Eigen/SVD
# zeo++-0.3/Eigen/PaStiXSupport
# zeo++-0.3/Eigen/SparseQR
# zeo++-0.3/Eigen/LU
# zeo++-0.3/Eigen/StdDeque
# zeo++-0.3/Eigen/StdList
# zeo++-0.3/Eigen/Dense
# zeo++-0.3/Eigen/QR
# zeo++-0.3/Eigen/Householder
# zeo++-0.3/Eigen/PardisoSupport
# zeo++-0.3/Eigen/Array
# zeo++-0.3/Eigen/SparseLU
# zeo++-0.3/Eigen/Eigen
# zeo++-0.3/Eigen/OrderingMethods
# zeo++-0.3/Eigen/CMakeLists.txt
# zeo++-0.3/Eigen/SPQRSupport
# zeo++-0.3/Eigen/Geometry
# zeo++-0.3/Eigen/src/
# zeo++-0.3/Eigen/src/MetisSupport/
# zeo++-0.3/Eigen/src/MetisSupport/MetisSupport.h
# zeo++-0.3/Eigen/src/MetisSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/plugins/
# zeo++-0.3/Eigen/src/plugins/CommonCwiseUnaryOps.h
# zeo++-0.3/Eigen/src/plugins/MatrixCwiseBinaryOps.h
# zeo++-0.3/Eigen/src/plugins/MatrixCwiseUnaryOps.h
# zeo++-0.3/Eigen/src/plugins/ArrayCwiseUnaryOps.h
# zeo++-0.3/Eigen/src/plugins/CommonCwiseBinaryOps.h
# zeo++-0.3/Eigen/src/plugins/CMakeLists.txt
# zeo++-0.3/Eigen/src/plugins/BlockMethods.h
# zeo++-0.3/Eigen/src/plugins/ArrayCwiseBinaryOps.h
# zeo++-0.3/Eigen/src/UmfPackSupport/
# zeo++-0.3/Eigen/src/UmfPackSupport/UmfPackSupport.h
# zeo++-0.3/Eigen/src/UmfPackSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/Eigen2Support/
# zeo++-0.3/Eigen/src/Eigen2Support/Memory.h
# zeo++-0.3/Eigen/src/Eigen2Support/VectorBlock.h
# zeo++-0.3/Eigen/src/Eigen2Support/Minor.h
# zeo++-0.3/Eigen/src/Eigen2Support/Lazy.h
# zeo++-0.3/Eigen/src/Eigen2Support/Meta.h
# zeo++-0.3/Eigen/src/Eigen2Support/LeastSquares.h
# zeo++-0.3/Eigen/src/Eigen2Support/QR.h
# zeo++-0.3/Eigen/src/Eigen2Support/Block.h
# zeo++-0.3/Eigen/src/Eigen2Support/CwiseOperators.h
# zeo++-0.3/Eigen/src/Eigen2Support/Cwise.h
# zeo++-0.3/Eigen/src/Eigen2Support/CMakeLists.txt
# zeo++-0.3/Eigen/src/Eigen2Support/Macros.h
# zeo++-0.3/Eigen/src/Eigen2Support/TriangularSolver.h
# zeo++-0.3/Eigen/src/Eigen2Support/LU.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Scaling.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Transform.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/All.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/AlignedBox.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Translation.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Hyperplane.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Quaternion.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/ParametrizedLine.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/AngleAxis.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/CMakeLists.txt
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/RotationBase.h
# zeo++-0.3/Eigen/src/Eigen2Support/Geometry/Rotation2D.h
# zeo++-0.3/Eigen/src/Eigen2Support/MathFunctions.h
# zeo++-0.3/Eigen/src/Eigen2Support/SVD.h
# zeo++-0.3/Eigen/src/SuperLUSupport/
# zeo++-0.3/Eigen/src/SuperLUSupport/SuperLUSupport.h
# zeo++-0.3/Eigen/src/SuperLUSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/CholmodSupport/
# zeo++-0.3/Eigen/src/CholmodSupport/CholmodSupport.h
# zeo++-0.3/Eigen/src/CholmodSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/SparseCore/
# zeo++-0.3/Eigen/src/SparseCore/SparseRedux.h
# zeo++-0.3/Eigen/src/SparseCore/MappedSparseMatrix.h
# zeo++-0.3/Eigen/src/SparseCore/SparseDot.h
# zeo++-0.3/Eigen/src/SparseCore/SparseSparseProductWithPruning.h
# zeo++-0.3/Eigen/src/SparseCore/SparseVector.h
# zeo++-0.3/Eigen/src/SparseCore/SparseTriangularView.h
# zeo++-0.3/Eigen/src/SparseCore/SparseColEtree.h
# zeo++-0.3/Eigen/src/SparseCore/SparseProduct.h
# zeo++-0.3/Eigen/src/SparseCore/SparseTranspose.h
# zeo++-0.3/Eigen/src/SparseCore/CompressedStorage.h
# zeo++-0.3/Eigen/src/SparseCore/SparseMatrix.h
# zeo++-0.3/Eigen/src/SparseCore/SparseSelfAdjointView.h
# zeo++-0.3/Eigen/src/SparseCore/SparseFuzzy.h
# zeo++-0.3/Eigen/src/SparseCore/SparseCwiseUnaryOp.h
# zeo++-0.3/Eigen/src/SparseCore/SparseDiagonalProduct.h
# zeo++-0.3/Eigen/src/SparseCore/ConservativeSparseSparseProduct.h
# zeo++-0.3/Eigen/src/SparseCore/SparseBlock.h
# zeo++-0.3/Eigen/src/SparseCore/SparseUtil.h
# zeo++-0.3/Eigen/src/SparseCore/SparseMatrixBase.h
# zeo++-0.3/Eigen/src/SparseCore/CMakeLists.txt
# zeo++-0.3/Eigen/src/SparseCore/AmbiVector.h
# zeo++-0.3/Eigen/src/SparseCore/SparseCwiseBinaryOp.h
# zeo++-0.3/Eigen/src/SparseCore/TriangularSolver.h
# zeo++-0.3/Eigen/src/SparseCore/SparseView.h
# zeo++-0.3/Eigen/src/SparseCore/SparsePermutation.h
# zeo++-0.3/Eigen/src/SparseCore/SparseDenseProduct.h
# zeo++-0.3/Eigen/src/Core/
# zeo++-0.3/Eigen/src/Core/Flagged.h
# zeo++-0.3/Eigen/src/Core/TriangularMatrix.h
# zeo++-0.3/Eigen/src/Core/Redux.h
# zeo++-0.3/Eigen/src/Core/DenseStorage.h
# zeo++-0.3/Eigen/src/Core/VectorBlock.h
# zeo++-0.3/Eigen/src/Core/Reverse.h
# zeo++-0.3/Eigen/src/Core/Transpositions.h
# zeo++-0.3/Eigen/src/Core/CoreIterators.h
# zeo++-0.3/Eigen/src/Core/Select.h
# zeo++-0.3/Eigen/src/Core/SelfCwiseBinaryOp.h
# zeo++-0.3/Eigen/src/Core/CwiseUnaryOp.h
# zeo++-0.3/Eigen/src/Core/ArrayWrapper.h
# zeo++-0.3/Eigen/src/Core/Transpose.h
# zeo++-0.3/Eigen/src/Core/Stride.h
# zeo++-0.3/Eigen/src/Core/SelfAdjointView.h
# zeo++-0.3/Eigen/src/Core/ForceAlignedAccess.h
# zeo++-0.3/Eigen/src/Core/CwiseBinaryOp.h
# zeo++-0.3/Eigen/src/Core/Diagonal.h
# zeo++-0.3/Eigen/src/Core/Array.h
# zeo++-0.3/Eigen/src/Core/DenseCoeffsBase.h
# zeo++-0.3/Eigen/src/Core/arch/
# zeo++-0.3/Eigen/src/Core/arch/Default/
# zeo++-0.3/Eigen/src/Core/arch/Default/Settings.h
# zeo++-0.3/Eigen/src/Core/arch/Default/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/arch/AltiVec/
# zeo++-0.3/Eigen/src/Core/arch/AltiVec/PacketMath.h
# zeo++-0.3/Eigen/src/Core/arch/AltiVec/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/arch/AltiVec/Complex.h
# zeo++-0.3/Eigen/src/Core/arch/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/arch/SSE/
# zeo++-0.3/Eigen/src/Core/arch/SSE/PacketMath.h
# zeo++-0.3/Eigen/src/Core/arch/SSE/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/arch/SSE/Complex.h
# zeo++-0.3/Eigen/src/Core/arch/SSE/MathFunctions.h
# zeo++-0.3/Eigen/src/Core/arch/NEON/
# zeo++-0.3/Eigen/src/Core/arch/NEON/PacketMath.h
# zeo++-0.3/Eigen/src/Core/arch/NEON/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/arch/NEON/Complex.h
# zeo++-0.3/Eigen/src/Core/DiagonalProduct.h
# zeo++-0.3/Eigen/src/Core/PlainObjectBase.h
# zeo++-0.3/Eigen/src/Core/GenericPacketMath.h
# zeo++-0.3/Eigen/src/Core/StableNorm.h
# zeo++-0.3/Eigen/src/Core/Block.h
# zeo++-0.3/Eigen/src/Core/MatrixBase.h
# zeo++-0.3/Eigen/src/Core/Swap.h
# zeo++-0.3/Eigen/src/Core/ProductBase.h
# zeo++-0.3/Eigen/src/Core/Assign_MKL.h
# zeo++-0.3/Eigen/src/Core/CwiseNullaryOp.h
# zeo++-0.3/Eigen/src/Core/BandMatrix.h
# zeo++-0.3/Eigen/src/Core/IO.h
# zeo++-0.3/Eigen/src/Core/Dot.h
# zeo++-0.3/Eigen/src/Core/GeneralProduct.h
# zeo++-0.3/Eigen/src/Core/CommaInitializer.h
# zeo++-0.3/Eigen/src/Core/PermutationMatrix.h
# zeo++-0.3/Eigen/src/Core/Fuzzy.h
# zeo++-0.3/Eigen/src/Core/EigenBase.h
# zeo++-0.3/Eigen/src/Core/Functors.h
# zeo++-0.3/Eigen/src/Core/VectorwiseOp.h
# zeo++-0.3/Eigen/src/Core/Matrix.h
# zeo++-0.3/Eigen/src/Core/NestByValue.h
# zeo++-0.3/Eigen/src/Core/NumTraits.h
# zeo++-0.3/Eigen/src/Core/GlobalFunctions.h
# zeo++-0.3/Eigen/src/Core/NoAlias.h
# zeo++-0.3/Eigen/src/Core/BooleanRedux.h
# zeo++-0.3/Eigen/src/Core/DenseBase.h
# zeo++-0.3/Eigen/src/Core/CMakeLists.txt
# zeo++-0.3/Eigen/src/Core/Replicate.h
# zeo++-0.3/Eigen/src/Core/SolveTriangular.h
# zeo++-0.3/Eigen/src/Core/Ref.h
# zeo++-0.3/Eigen/src/Core/ReturnByValue.h
# zeo++-0.3/Eigen/src/Core/MapBase.h
# zeo++-0.3/Eigen/src/Core/Assign.h
# zeo++-0.3/Eigen/src/Core/Map.h
# zeo++-0.3/Eigen/src/Core/products/
# zeo++-0.3/Eigen/src/Core/products/TriangularSolverMatrix_MKL.h
# zeo++-0.3/Eigen/src/Core/products/GeneralMatrixMatrix.h
# zeo++-0.3/Eigen/src/Core/products/SelfadjointMatrixMatrix.h
# zeo++-0.3/Eigen/src/Core/products/Parallelizer.h
# zeo++-0.3/Eigen/src/StlSupport/StdList.h
# zeo++-0.3/Eigen/src/StlSupport/details.h
# zeo++-0.3/Eigen/src/StlSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/StlSupport/StdDeque.h
# zeo++-0.3/Eigen/src/Jacobi/
# zeo++-0.3/Eigen/src/Jacobi/Jacobi.h
# zeo++-0.3/Eigen/src/Jacobi/CMakeLists.txt
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/IncompleteLUT.h
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/BasicPreconditioners.h
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/IterativeSolverBase.h
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/CMakeLists.txt
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/BiCGSTAB.h
# zeo++-0.3/Eigen/src/IterativeLinearSolvers/ConjugateGradient.h
# zeo++-0.3/Eigen/src/SVD/
# zeo++-0.3/Eigen/src/SVD/UpperBidiagonalization.h
# zeo++-0.3/Eigen/src/SVD/JacobiSVD_MKL.h
# zeo++-0.3/Eigen/src/SVD/JacobiSVD.h
# zeo++-0.3/Eigen/src/SVD/CMakeLists.txt
# zeo++-0.3/Eigen/src/PaStiXSupport/
# zeo++-0.3/Eigen/src/PaStiXSupport/PaStiXSupport.h
# zeo++-0.3/Eigen/src/PaStiXSupport/CMakeLists.txt
# zeo++-0.3/Eigen/src/SparseQR/
# zeo++-0.3/Eigen/src/SparseQR/SparseQR.h
# zeo++-0.3/Eigen/src/SparseQR/CMakeLists.txt
# zeo++-0.3/Eigen/src/LU/
# zeo++-0.3/Eigen/src/LU/Determinant.h
# zeo++-0.3/Eigen/src/LU/FullPivLU.h
# zeo++-0.3/Eigen/src/LU/PartialPivLU.h
# zeo++-0.3/Eigen/src/LU/arch/
# zeo++-0.3/Eigen/src/LU/arch/Inverse_SSE.h
# zeo++-0.3/Eigen/src/LU/arch/CMakeLists.txt
# zeo++-0.3/Eigen/src/LU/Inverse.h
# zeo++-0.3/Eigen/src/LU/PartialPivLU_MKL.h
# zeo++-0.3/Eigen/src/LU/CMakeLists.txt
# zeo++-0.3/Eigen/src/misc/
# zeo++-0.3/Eigen/src/misc/Image.h
# zeo++-0.3/Eigen/src/misc/SparseSolve.h
# zeo++-0.3/Eigen/src/misc/blas.h
# zeo++-0.3/Eigen/src/misc/Solve.h
# zeo++-0.3/Eigen/src/misc/CMakeLists.txt
# zeo++-0.3/Eigen/src/misc/Kernel.h
# zeo++-0.3/Eigen/src/QR/
# zeo++-0.3/Eigen/src/QR/HouseholderQR_MKL.h
# zeo++-0.3/Eigen/src/QR/HouseholderQR.h
# zeo++-0.3/Eigen/src/QR/ColPivHouseholderQR.h
# zeo++-0.3/Eigen/src/QR/FullPivHouseholderQR.h
# zeo++-0.3/Eigen/src/QR/CMakeLists.txt
# zeo++-0.3/Eigen/src/QR/ColPivHouseholderQR_MKL.h
# zeo++-0.3/Eigen/src/Householder/
# zeo++-0.3/Eigen/src/Eigenvalues/ComplexSchur_MKL.h
# zeo++-0.3/Eigen/src/Eigenvalues/EigenSolver.h
# zeo++-0.3/Eigen/src/Eigenvalues/SelfAdjointEigenSolver.h
# zeo++-0.3/Eigen/src/Eigenvalues/HessenbergDecomposition.h
# zeo++-0.3/Eigen/src/Eigenvalues/GeneralizedEigenSolver.h
# zeo++-0.3/Eigen/src/Eigenvalues/SelfAdjointEigenSolver_MKL.h
# zeo++-0.3/Eigen/src/Eigenvalues/Tridiagonalization.h
# zeo++-0.3/Eigen/src/Eigenvalues/ComplexEigenSolver.h
# zeo++-0.3/Eigen/src/Eigenvalues/RealQZ.h
# zeo++-0.3/Eigen/src/Eigenvalues/CMakeLists.txt
# zeo++-0.3/Eigen/src/Eigenvalues/GeneralizedSelfAdjointEigenSolver.h
# zeo++-0.3/Eigen/src/Eigenvalues/RealSchur_MKL.h
# zeo++-0.3/Eigen/src/Eigenvalues/MatrixBaseEigenvalues.h
# zeo++-0.3/Eigen/src/Eigenvalues/RealSchur.h
# zeo++-0.3/Eigen/StdVector
# zeo++-0.3/Eigen/SparseCholesky
# zeo++-0.3/Eigen/Eigenvalues
# zeo++-0.3/cluster.cc
# zeo++-0.3/grid.h
# zeo++-0.3/UNITTEST/
# zeo++-0.3/UNITTEST/EDI.cssr
# zeo++-0.3/UNITTEST/EDI.vol
# zeo++-0.3/UNITTEST/EDI.chan
# zeo++-0.3/UNITTEST/history_1000.vol
# zeo++-0.3/UNITTEST/history_1000.cssr
# zeo++-0.3/UNITTEST/COMMANDS.txt
# zeo++-0.3/UNITTEST/history_1000.sa
# zeo++-0.3/UNITTEST/EDI.sa
# zeo++-0.3/UNITTEST/EDI.res
# zeo++-0.3/UNITTEST/EDI.psd_histo
# zeo++-0.3/UNITTEST/history_1000.res
# zeo++-0.3/main.cc
# zeo++-0.3/NEWS
# zeo++-0.3/rmsd.cc
# zeo++-0.3/octree.cpp
# zeo++-0.3/nets/
# zeo++-0.3/nets/hcb.cgd
# zeo++-0.3/nets/pts.cgd
# zeo++-0.3/nets/dia-c5.cgd
# zeo++-0.3/nets/tbo.cgd
# zeo++-0.3/nets/pyr.cgd
# zeo++-0.3/nets/rhr.cgd
# zeo++-0.3/nets/ntt_simple.cgd
# zeo++-0.3/nets/dia.cgd
# zeo++-0.3/nets/qom.cgd
# zeo++-0.3/voro++/
# zeo++-0.3/voro++/zeo/
# zeo++-0.3/voro++/zeo/cp_test.cc
# zeo++-0.3/voro++/zeo/v_network.hh
# zeo++-0.3/voro++/zeo/Makefile
# zeo++-0.3/voro++/zeo/r_table.cc
# zeo++-0.3/voro++/zeo/network.cc
# zeo++-0.3/voro++/zeo/images.cc
# zeo++-0.3/voro++/zeo/examples/
# zeo++-0.3/voro++/zeo/examples/EDI.v1
# zeo++-0.3/voro++/zeo/examples/test.v1
# zeo++-0.3/voro++/zeo/examples/BIK.v1
# zeo++-0.3/voro++/zeo/examples/P2.v1
# zeo++-0.3/voro++/zeo/examples/AFX.v1
# zeo++-0.3/voro++/zeo/examples/P4.v1
# zeo++-0.3/voro++/zeo/examples/YUG.v1
# zeo++-0.3/voro++/zeo/examples/EMT.v1
# zeo++-0.3/voro++/zeo/examples/P3.v1
# zeo++-0.3/voro++/zeo/examples/JBW.v1
# zeo++-0.3/voro++/zeo/examples/HV.v1
# zeo++-0.3/voro++/zeo/examples/HEU.v1
# zeo++-0.3/voro++/zeo/examples/IFR.v1
# zeo++-0.3/voro++/zeo/examples/P1.v1
# zeo++-0.3/voro++/zeo/v_network.cc
# zeo++-0.3/voro++/zeo/cp_test.gnuplot
# zeo++-0.3/voro++/html/
# zeo++-0.3/voro++/scripts/
# zeo++-0.3/voro++/scripts/random.pl
# zeo++-0.3/voro++/scripts/network.pl
# zeo++-0.3/voro++/scripts/sum.pl
# zeo++-0.3/voro++/scripts/README
# zeo++-0.3/voro++/Makefile
# zeo++-0.3/voro++/LICENSE
# zeo++-0.3/voro++/man/
# zeo++-0.3/voro++/man/voro++.1
# zeo++-0.3/voro++/config.mk
# zeo++-0.3/voro++/NEWS
# zeo++-0.3/voro++/examples/
# zeo++-0.3/voro++/examples/interface/
# zeo++-0.3/voro++/examples/interface/polygons4.pov
# zeo++-0.3/voro++/examples/interface/polygons6.pov
# zeo++-0.3/voro++/examples/interface/Makefile
# zeo++-0.3/voro++/examples/interface/loops.cc
# zeo++-0.3/voro++/examples/interface/polygons.cc
# zeo++-0.3/voro++/examples/interface/find_voro_cell.cc
# zeo++-0.3/voro++/examples/interface/odd_even.pov
# zeo++-0.3/voro++/examples/interface/odd_even.cc
# zeo++-0.3/voro++/examples/interface/loops.pov
# zeo++-0.3/voro++/examples/interface/polygons5.pov
# zeo++-0.3/voro++/examples/interface/README
# zeo++-0.3/voro++/examples/interface/pack_six_cube
# zeo++-0.3/voro++/examples/extra/
# zeo++-0.3/voro++/examples/extra/l_shape.cc
# zeo++-0.3/voro++/examples/extra/superellipsoid.cc
# zeo++-0.3/voro++/examples/extra/cut_region.cc
# zeo++-0.3/voro++/examples/extra/Makefile
# zeo++-0.3/voro++/examples/extra/pack_irregular
# zeo++-0.3/voro++/examples/extra/irregular.cc
# zeo++-0.3/voro++/examples/extra/README
# zeo++-0.3/voro++/examples/extra/box_cut.cc
# zeo++-0.3/voro++/examples/extra/superellipsoid.pov
# zeo++-0.3/voro++/examples/extra/irregular.pov
# zeo++-0.3/voro++/examples/basic/
# zeo++-0.3/voro++/examples/basic/convex_test.cc
# zeo++-0.3/voro++/examples/basic/Makefile
# zeo++-0.3/voro++/examples/basic/import.pov
# zeo++-0.3/voro++/examples/basic/import.cc
# zeo++-0.3/voro++/examples/basic/single_cell.cc
# zeo++-0.3/voro++/examples/basic/pack_ten_cube
# zeo++-0.3/voro++/examples/basic/random_points.cc
# zeo++-0.3/voro++/examples/basic/platonic.cc
# zeo++-0.3/voro++/examples/basic/README
# zeo++-0.3/voro++/examples/Makefile
# zeo++-0.3/voro++/examples/timing/
# zeo++-0.3/voro++/examples/custom/pack_six_cube_poly.pov
# zeo++-0.3/voro++/examples/custom/radical.cc
# zeo++-0.3/voro++/examples/walls/
# zeo++-0.3/voro++/examples/walls/pack_cylinder
# zeo++-0.3/voro++/examples/walls/tetrahedron.cc
# zeo++-0.3/voro++/examples/walls/Makefile
# zeo++-0.3/voro++/examples/walls/frustum.cc
# zeo++-0.3/voro++/examples/walls/cylinder.pov
# zeo++-0.3/voro++/examples/walls/tetrahedron.pov
# zeo++-0.3/voro++/examples/walls/pack_torus
# zeo++-0.3/voro++/examples/walls/frustum.pov
# zeo++-0.3/voro++/examples/walls/cylinder.cc
# zeo++-0.3/voro++/examples/walls/torus.pov
# zeo++-0.3/voro++/examples/walls/torus.cc
# zeo++-0.3/voro++/examples/walls/README
# zeo++-0.3/voro++/src/
# zeo++-0.3/voro++/src/Makefile.dep
# zeo++-0.3/voro++/src/container_prd.cc
# zeo++-0.3/voro++/src/wall.hh
# zeo++-0.3/voro++/src/worklist.hh
# zeo++-0.3/voro++/src/v_compute.cc
# zeo++-0.3/voro++/src/cell.cc
# zeo++-0.3/voro++/src/cell.hh
# zeo++-0.3/voro++/src/c_loops.cc
# zeo++-0.3/voro++/src/pre_container.hh
# zeo++-0.3/voro++/src/Makefile
# zeo++-0.3/voro++/src/v_base.hh
# zeo++-0.3/voro++/src/container_prd.hh
# zeo++-0.3/voro++/src/c_loops.hh
# zeo++-0.3/voro++/src/common.hh
# zeo++-0.3/voro++/src/wall.cc
# zeo++-0.3/voro++/src/container.cc
# zeo++-0.3/voro++/src/v_base_wl.cc
# zeo++-0.3/voro++/src/v_compute.hh
# zeo++-0.3/voro++/src/pre_container.cc
# zeo++-0.3/voro++/src/voro++.cc
# zeo++-0.3/voro++/src/unitcell.cc
# zeo++-0.3/voro++/src/container.hh
# zeo++-0.3/voro++/src/voro++.hh
# zeo++-0.3/voro++/src/worklist_gen.pl
# zeo++-0.3/voro++/src/config.hh
# zeo++-0.3/voro++/src/v_base.cc
# zeo++-0.3/voro++/src/cmd_line.cc
# zeo++-0.3/voro++/src/common.cc
# zeo++-0.3/voro++/src/Doxyfile
# zeo++-0.3/voro++/src/README
# zeo++-0.3/voro++/src/rad_option.hh
# zeo++-0.3/voro++/src/unitcell.hh
# zeo++-0.3/voro++/README
# zeo++-0.3/cluster.h
# zeo++-0.3/mindist.cc
# zeo++-0.3/networkanalysis.h
# zeo++-0.3/holograms.h
# zeo++-0.3/gpu_energy.cc
# zeo++-0.3/psd.cc
# zeo++-0.3/material.h
# zeo++-0.3/net.cc
# zeo++-0.3/diversity_selection_holos.c
# zeo++-0.3/README
# zeo++-0.3/graphstorage.h
# zeo++-0.3/area_and_volume.h
# zeo++-0.3/networkaccessibility.cc
# zeo++-0.3/v_network.cc
# zeo++-0.3/documentation/
# zeo++-0.3/documentation/README_rich_test
# zeo++-0.3/documentation/example.mass
# zeo++-0.3/documentation/example.rad
# zeo++-0.3/documentation/README
# zeo++-0.3/networkio.h
# zeo++-0.3/geometry.cc
# zeo++-0.3/symmetry.cc
# zeo++-0.3/networkstorage.cc
# zeo++-0.3/OMS.cc
# zeo++-0.3/R/
# zeo++-0.3/R/parameters.R
# zeo++-0.3/R/noninteractive_graph_shell.R
# zeo++-0.3/R/R_PSD_shell_plot.pdf
# zeo++-0.3/R/noninteractive_graph_functions.R

# %%
# !cd zeo++-0.3/voro++/src && make
# Out:
# g++ -Wall -ansi -pedantic -O3 -c cell.cc
# cell.cc: In member function ‘void voro::voronoicell_base::add_memory_vorder(vc_class&)’:
# cell.cc:231:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   231 |         for(j=0;j<current_vertex_order;j++) p1[j]=mem[j];while(j<i) p1[j++]=0;
#       |         ^~~
# cell.cc:231:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   231 |         for(j=0;j<current_vertex_order;j++) p1[j]=mem[j];while(j<i) p1[j++]=0;
#       |                                                          ^~~~~
# cell.cc:237:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   237 |         for(j=0;j<current_vertex_order;j++) p1[j]=mec[j];while(j<i) p1[j++]=0;
#       |         ^~~
# cell.cc:237:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   237 |         for(j=0;j<current_vertex_order;j++) p1[j]=mec[j];while(j<i) p1[j++]=0;
#       |                                                          ^~~~~
# cell.cc: In member function ‘void voro::voronoicell_base::init_base(double, double, double, double, double, double)’:
# cell.cc:293:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   293 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |         ^~~
# cell.cc:293:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   293 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |                                                          ^~
# cell.cc: In member function ‘void voro::voronoicell::init_l_shape()’:
# cell.cc:320:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   320 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |         ^~~
# cell.cc:320:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   320 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |                                                          ^~
# cell.cc: In member function ‘void voro::voronoicell_base::init_octahedron_base(double)’:
# cell.cc:359:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   359 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |         ^~~
# cell.cc:359:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   359 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |                                                          ^~
# cell.cc: In member function ‘void voro::voronoicell_base::init_tetrahedron_base(double, double, double, double, double, double, double, double, double, double, double, double)’:
# cell.cc:385:9: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   385 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |         ^~~
# cell.cc:385:58: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   385 |         for(int i=0;i<current_vertex_order;i++) mec[i]=0;up=0;
#       |                                                          ^~
# g++ -Wall -ansi -pedantic -O3 -c common.cc
# g++ -Wall -ansi -pedantic -O3 -c container.cc
# g++ -Wall -ansi -pedantic -O3 -c unitcell.cc
# g++ -Wall -ansi -pedantic -O3 -c v_compute.cc
# v_compute.cc: In member function ‘void voro::voro_compute<c_class>::add_list_memory(int*&, int*&)’:
# v_compute.cc:976:17: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#   976 |                 while(qu_s<qu_l) *(qu_c++)=*(qu_s++);qu_s=qu;
#       |                 ^~~~~
# v_compute.cc:976:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#   976 |                 while(qu_s<qu_l) *(qu_c++)=*(qu_s++);qu_s=qu;
#       |                                                      ^~~~
# g++ -Wall -ansi -pedantic -O3 -c c_loops.cc
# g++ -Wall -ansi -pedantic -O3 -c v_base.cc
# g++ -Wall -ansi -pedantic -O3 -c wall.cc
# g++ -Wall -ansi -pedantic -O3 -c pre_container.cc
# g++ -Wall -ansi -pedantic -O3 -c container_prd.cc
# rm -f libvoro++.a
# ar rs libvoro++.a cell.o common.o container.o unitcell.o v_compute.o c_loops.o v_base.o wall.o pre_container.o container_prd.o
# ar: creating libvoro++.a
# g++ -Wall -ansi -pedantic -O3 -L. -o voro++ cmd_line.cc -lvoro++

# %%
# !cd zeo++-0.3/ && make
# Out:
# g++ -Ivoro++/src  -g  -c network.cc
# In file included from Eigen/Core:263,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/arch/SSE/PacketMath.h:29:39: warning: ignoring attributes on template argument ‘__m128’ [-Wignored-attributes]
#    29 | template<> struct is_arithmetic<__m128>  { enum { value = true }; };
#       |                                       ^
# Eigen/src/Core/arch/SSE/PacketMath.h:30:40: warning: ignoring attributes on template argument ‘__m128i’ [-Wignored-attributes]
#    30 | template<> struct is_arithmetic<__m128i> { enum { value = true }; };
#       |                                        ^
# Eigen/src/Core/arch/SSE/PacketMath.h:31:40: warning: ignoring attributes on template argument ‘__m128d’ [-Wignored-attributes]
#    31 | template<> struct is_arithmetic<__m128d> { enum { value = true }; };
#       |                                        ^
# Eigen/src/Core/arch/SSE/PacketMath.h:101:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   101 | template<> struct unpacket_traits<Packet4f> { typedef float  type; enum {size=4}; };
#       |                                           ^
# Eigen/src/Core/arch/SSE/PacketMath.h:102:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   102 | template<> struct unpacket_traits<Packet2d> { typedef double type; enum {size=2}; };
#       |                                           ^
# Eigen/src/Core/arch/SSE/PacketMath.h:103:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   103 | template<> struct unpacket_traits<Packet4i> { typedef int    type; enum {size=4}; };
#       |                                           ^
# In file included from Eigen/Core:263,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/arch/SSE/PacketMath.h:586:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   586 | struct palign_impl<Offset,Packet4f>
#       |                                   ^
# Eigen/src/Core/arch/SSE/PacketMath.h:609:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   609 | struct palign_impl<Offset,Packet4i>
#       |                                   ^
# Eigen/src/Core/arch/SSE/PacketMath.h:632:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   632 | struct palign_impl<Offset,Packet2d>
#       |                                   ^
# In file included from Eigen/Core:265,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/arch/SSE/Complex.h:211:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   211 | template<> struct conj_helper<Packet4f, Packet2cf, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:220:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   220 | template<> struct conj_helper<Packet2cf, Packet4f, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:407:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   407 | template<> struct conj_helper<Packet2d, Packet1cd, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:416:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   416 | template<> struct conj_helper<Packet1cd, Packet2d, false,false>
#       |                                                               ^
# In file included from Eigen/Core:276,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/Functors.h:973:28: warning: ‘template<class _Operation> class std::binder2nd’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   973 | struct functor_traits<std::binder2nd<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/include/c++/11/bits/stl_function.h:1421,
#                  from /usr/include/c++/11/bits/stl_tree.h:65,
#                  from /usr/include/c++/11/map:60,
#                  from network.h:18,
#                  from network.cc:14:
# /usr/include/c++/11/backward/binders.h:143:11: note: declared here
#   143 |     class binder2nd
#       |           ^~~~~~~~~
# In file included from Eigen/Core:276,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/Functors.h:977:28: warning: ‘template<class _Operation> class std::binder1st’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   977 | struct functor_traits<std::binder1st<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/include/c++/11/bits/stl_function.h:1421,
#                  from /usr/include/c++/11/bits/stl_tree.h:65,
#                  from /usr/include/c++/11/map:60,
#                  from network.h:18,
#                  from network.cc:14:
# /usr/include/c++/11/backward/binders.h:108:11: note: declared here
#   108 |     class binder1st
#       |           ^~~~~~~~~
# In file included from Eigen/Core:277,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from network.cc:21:
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<float, 4, 1>, float, float, Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<float, 4, 1>’
# Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<float>’
# Eigen/src/Geometry/arch/Geometry_SSE.h:22:3:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<float>::type’ {aka ‘__m128’} [-Wignored-attributes]
#    56 |                      >::type PacketReturnType;
#       |                              ^~~~~~~~~~~~~~~~
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 4, 1>, double, double, Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 4, 1>’
# Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<double>’
# Eigen/src/Geometry/arch/Geometry_SSE.h:63:3:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# network.cc: In function ‘void* performVoronoiDecomp(bool, ATOM_NETWORK*, VORONOI_NETWORK*, std::vector<VOR_CELL>&, bool, std::vector<BASIC_VCELL>&)’:
# network.cc:171:1: warning: control reaches end of non-void function [-Wreturn-type]
#   171 | }
#       | ^
# g++ -Ivoro++/src  -g  -c networkinfo.cc
# g++ -Ivoro++/src  -g  -c networkio.cc
# g++ -Ivoro++/src  -g  -c instructions.cc
# g++ -Ivoro++/src  -g  -c networkanalysis.cc
# g++ -Ivoro++/src  -g  -c area_and_volume.cc
# g++ -Ivoro++/src  -g  -c segment.cc
# g++ -Ivoro++/src  -g  -c string_additions.cc
# g++ -Ivoro++/src  -g  -c symbcalc.cc
# g++ -Ivoro++/src  -g  -c ray.cc
# g++ -Ivoro++/src  -g  -c graphstorage.cc
# g++ -Ivoro++/src  -g  -c networkstorage.cc
# g++ -Ivoro++/src  -g  -c voronoicell.cc
# g++ -Ivoro++/src  -g  -c channel.cc
# g++ -Ivoro++/src  -g  -c mindist.cc
# g++ -Ivoro++/src  -g  -c feature.cc
# g++ -Ivoro++/src  -g  -c v_network.cc
# g++ -Ivoro++/src  -g  -c geometry.cc
# geometry.cc: In function ‘std::ostream& operator<<(std::ostream&, Point&)’:
# geometry.cc:143:1: warning: no return statement in function returning non-void [-Wreturn-type]
#   143 | }
#       | ^
# g++ -Ivoro++/src  -g  -c holograms.cc
# g++ -Ivoro++/src  -g  -c grid.cc
# g++ -Ivoro++/src  -g  -c psd.cc
# g++ -Ivoro++/src  -g  -c sphere_approx.cc
# g++ -Ivoro++/src  -g  -c networkaccessibility.cc
# g++ -Ivoro++/src  -g  -c poreinfo.cc
# g++ -Ivoro++/src  -g  -c cluster.cc
# g++ -Ivoro++/src  -g  -c net.cc
# net.cc: In function ‘int assign_dummy_site(MOLECULE*)’:
# net.cc:183:1: warning: control reaches end of non-void function [-Wreturn-type]
#   183 | }
#       | ^
# g++ -Ivoro++/src  -g  -c rmsd.cc
# g++ -Ivoro++/src  -g  -c symmetry.cc
# g++ -Ivoro++/src  -g  -c cycle.cc
# g++ -Ivoro++/src  -g  -c arguments.cc
# g++ -Ivoro++/src  -g  -c material.cc
# g++ -Ivoro++/src  -g  -c OMS.cc
# In file included from Eigen/Core:263,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/arch/SSE/PacketMath.h:29:39: warning: ignoring attributes on template argument ‘__m128’ [-Wignored-attributes]
#    29 | template<> struct is_arithmetic<__m128>  { enum { value = true }; };
#       |                                       ^
# Eigen/src/Core/arch/SSE/PacketMath.h:30:40: warning: ignoring attributes on template argument ‘__m128i’ [-Wignored-attributes]
#    30 | template<> struct is_arithmetic<__m128i> { enum { value = true }; };
#       |                                        ^
# Eigen/src/Core/arch/SSE/PacketMath.h:31:40: warning: ignoring attributes on template argument ‘__m128d’ [-Wignored-attributes]
#    31 | template<> struct is_arithmetic<__m128d> { enum { value = true }; };
#       |                                        ^
# Eigen/src/Core/arch/SSE/PacketMath.h:101:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   101 | template<> struct unpacket_traits<Packet4f> { typedef float  type; enum {size=4}; };
#       |                                           ^
# Eigen/src/Core/arch/SSE/PacketMath.h:102:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   102 | template<> struct unpacket_traits<Packet2d> { typedef double type; enum {size=2}; };
#       |                                           ^
# Eigen/src/Core/arch/SSE/PacketMath.h:103:43: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   103 | template<> struct unpacket_traits<Packet4i> { typedef int    type; enum {size=4}; };
#       |                                           ^
# In file included from Eigen/Core:263,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/arch/SSE/PacketMath.h:586:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   586 | struct palign_impl<Offset,Packet4f>
#       |                                   ^
# Eigen/src/Core/arch/SSE/PacketMath.h:609:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4i’ {aka ‘__m128i’} [-Wignored-attributes]
#   609 | struct palign_impl<Offset,Packet4i>
#       |                                   ^
# Eigen/src/Core/arch/SSE/PacketMath.h:632:35: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   632 | struct palign_impl<Offset,Packet2d>
#       |                                   ^
# In file included from Eigen/Core:265,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/arch/SSE/Complex.h:211:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   211 | template<> struct conj_helper<Packet4f, Packet2cf, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:220:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet4f’ {aka ‘__m128’} [-Wignored-attributes]
#   220 | template<> struct conj_helper<Packet2cf, Packet4f, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:407:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   407 | template<> struct conj_helper<Packet2d, Packet1cd, false,false>
#       |                                                               ^
# Eigen/src/Core/arch/SSE/Complex.h:416:63: warning: ignoring attributes on template argument ‘Eigen::internal::Packet2d’ {aka ‘__m128d’} [-Wignored-attributes]
#   416 | template<> struct conj_helper<Packet1cd, Packet2d, false,false>
#       |                                                               ^
# In file included from Eigen/Core:276,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/Functors.h:973:28: warning: ‘template<class _Operation> class std::binder2nd’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   973 | struct functor_traits<std::binder2nd<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/include/c++/11/bits/stl_function.h:1421,
#                  from /usr/include/c++/11/functional:49,
#                  from /usr/include/c++/11/pstl/glue_algorithm_defs.h:13,
#                  from /usr/include/c++/11/algorithm:74,
#                  from OMS.h:16,
#                  from OMS.cc:11:
# /usr/include/c++/11/backward/binders.h:143:11: note: declared here
#   143 |     class binder2nd
#       |           ^~~~~~~~~
# In file included from Eigen/Core:276,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/Functors.h:977:28: warning: ‘template<class _Operation> class std::binder1st’ is deprecated: use 'std::bind' instead [-Wdeprecated-declarations]
#   977 | struct functor_traits<std::binder1st<T> >
#       |                            ^~~~~~~~~
# In file included from /usr/include/c++/11/bits/stl_function.h:1421,
#                  from /usr/include/c++/11/functional:49,
#                  from /usr/include/c++/11/pstl/glue_algorithm_defs.h:13,
#                  from /usr/include/c++/11/algorithm:74,
#                  from OMS.h:16,
#                  from OMS.cc:11:
# /usr/include/c++/11/backward/binders.h:108:11: note: declared here
#   108 |     class binder1st
#       |           ^~~~~~~~~
# In file included from Eigen/Core:277,
#                  from Eigen/Dense:1,
#                  from OMS.h:22,
#                  from OMS.cc:11:
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<float, 4, 1>, float, float, Eigen::DenseCoeffsBase<Eigen::Matrix<float, 4, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<float, 4, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<float, 4, 1>’
# Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<float>’
# Eigen/src/Geometry/arch/Geometry_SSE.h:22:3:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<float>::type’ {aka ‘__m128’} [-Wignored-attributes]
#    56 |                      >::type PacketReturnType;
#       |                              ^~~~~~~~~~~~~~~~
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 4, 1>, double, double, Eigen::DenseCoeffsBase<Eigen::Matrix<double, 4, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 4, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 4, 1>’
# Eigen/src/Geometry/Quaternion.h:282:16:   required from ‘class Eigen::Quaternion<double>’
# Eigen/src/Geometry/arch/Geometry_SSE.h:63:3:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 3, 1>, double, double, Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 3, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 3, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 3, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 3, 1>’
# OMS.cc:70:14:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 3>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 3>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 3>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 3, 3>, double, double, Eigen::DenseCoeffsBase<Eigen::Matrix<double, 3, 3>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 3, 3> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 3, 3> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 3, 3> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 3, 3>’
# OMS.cc:101:11:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<int, 3, 1>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<int, 3, 1>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<int, 3, 1>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<int, 3, 1>, int, int, Eigen::DenseCoeffsBase<Eigen::Matrix<int, 3, 1>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<int, 3, 1> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<int, 3, 1> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<int, 3, 1> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<int, 3, 1>’
# Eigen/src/Core/PermutationMatrix.h:74:13:   required from ‘class Eigen::PermutationBase<Eigen::PermutationMatrix<3, 3, int> >’
# Eigen/src/Core/PermutationMatrix.h:312:7:   required from ‘class Eigen::PermutationMatrix<3, 3, int>’
# Eigen/src/QR/ColPivHouseholderQR.h:62:45:   required from ‘class Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<int>::type’ {aka ‘__m128i’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 1, 3>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 1, 3>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Matrix<double, 1, 3>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Matrix<double, 1, 3>, double, double, Eigen::DenseCoeffsBase<Eigen::Matrix<double, 1, 3>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Matrix<double, 1, 3> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Matrix<double, 1, 3> >’
# Eigen/src/Core/PlainObjectBase.h:88:7:   required from ‘class Eigen::PlainObjectBase<Eigen::Matrix<double, 1, 3> >’
# Eigen/src/Core/Matrix.h:127:7:   required from ‘class Eigen::Matrix<double, 1, 3>’
# Eigen/src/QR/ColPivHouseholderQR.h:397:19:   required from ‘class Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >, 1>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >, double, double, Eigen::DenseCoeffsBase<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >, 1>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > > >’
# Eigen/src/Core/ReturnByValue.h:50:34:   required from ‘class Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >’
# Eigen/src/misc/Solve.h:32:60:   required from ‘struct Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >’
# Eigen/src/QR/ColPivHouseholderQR.h:518:8:   required from ‘struct Eigen::internal::solve_retval<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >’
# OMS.cc:133:35:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> >, 0>’:
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> >, double, double, Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> >, 0>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> > >’
# Eigen/src/Core/CwiseUnaryOp.h:92:7:   required from ‘class Eigen::CwiseUnaryOpImpl<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1>, Eigen::Dense>’
# Eigen/src/Core/CwiseUnaryOp.h:59:7:   required from ‘class Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Matrix<double, 3, 1> >’
# OMS.cc:287:17:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> >, 0>’:
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> >, double, double, Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> >, 0>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> > >’
# Eigen/src/Core/CwiseUnaryOp.h:92:7:   required from ‘class Eigen::CwiseUnaryOpImpl<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1>, Eigen::Dense>’
# Eigen/src/Core/CwiseUnaryOp.h:59:7:   required from ‘class Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Matrix<double, 3, 1> >’
# Eigen/src/Core/Dot.h:115:40:   required from ‘typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real Eigen::MatrixBase<Derived>::squaredNorm() const [with Derived = Eigen::Matrix<double, 3, 1>; typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real = double; typename Eigen::internal::traits<T>::Scalar = double]’
# Eigen/src/Core/Dot.h:128:15:   required from ‘typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real Eigen::MatrixBase<Derived>::norm() const [with Derived = Eigen::Matrix<double, 3, 1>; typename Eigen::NumTraits<typename Eigen::internal::traits<T>::Scalar>::Real = double; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:291:21:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 3 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:149:7:   required from ‘class Eigen::BlockImpl<Eigen::Matrix<double, 3, 3>, 3, 1, true, Eigen::Dense>’
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>’
# Eigen/src/QR/ColPivHouseholderQR.h:451:40:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 4 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Matrix<double, 1, 3>, 1, -1, false>’
# Eigen/src/Core/VectorBlock.h:57:47:   required from ‘class Eigen::VectorBlock<Eigen::Matrix<double, 1, 3>, -1>’
# Eigen/src/QR/ColPivHouseholderQR.h:462:55:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 4 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1, 1, false>’
# Eigen/src/Core/VectorBlock.h:57:47:   required from ‘class Eigen::VectorBlock<Eigen::Block<Eigen::Matrix<double, 3, 3>, 3, 1, true>, -1>’
# Eigen/src/QR/ColPivHouseholderQR.h:469:59:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 3 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:149:7:   required from ‘class Eigen::BlockImpl<Eigen::Matrix<double, 3, 3>, -1, -1, false, Eigen::Dense>’
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Matrix<double, 3, 3>, -1, -1, false>’
# Eigen/src/QR/ColPivHouseholderQR.h:498:27:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 3 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:149:7:   required from ‘class Eigen::BlockImpl<Eigen::Matrix<double, 3, 3>, 1, 3, false, Eigen::Dense>’
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>’
# Eigen/src/QR/ColPivHouseholderQR.h:502:44:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 4 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/Block.h:103:81:   required from ‘class Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false>’
# Eigen/src/Core/VectorBlock.h:57:47:   required from ‘class Eigen::VectorBlock<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, -1>’
# Eigen/src/QR/ColPivHouseholderQR.h:502:52:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>& Eigen::ColPivHouseholderQR<MatrixType>::compute(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:120:7:   required from ‘Eigen::ColPivHouseholderQR<MatrixType>::ColPivHouseholderQR(const MatrixType&) [with _MatrixType = Eigen::Matrix<double, 3, 3>; Eigen::ColPivHouseholderQR<MatrixType>::MatrixType = Eigen::Matrix<double, 3, 3>]’
# Eigen/src/QR/ColPivHouseholderQR.h:575:10:   required from ‘const Eigen::ColPivHouseholderQR<Eigen::Matrix<typename Eigen::internal::traits<T>::Scalar, Eigen::internal::traits<T>::RowsAtCompileTime, Eigen::internal::traits<T>::ColsAtCompileTime, (Eigen::AutoAlign | ((Eigen::internal::traits<T>::Flags & Eigen::RowMajorBit) ? Eigen::RowMajor :  Eigen::ColMajor)), Eigen::internal::traits<T>::MaxRowsAtCompileTime, Eigen::internal::traits<T>::MaxColsAtCompileTime> > Eigen::MatrixBase<Derived>::colPivHouseholderQr() const [with Derived = Eigen::Matrix<double, 3, 3>; typename Eigen::internal::traits<T>::Scalar = double]’
# OMS.cc:133:27:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> >, 0>’:
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> >, double, double, Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> >, 0>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_abs2_op<double>, const Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 3>, 1, 3, false>, 1, -1, false> > >’
# ...
# OMS.cc:133:37:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, double, double, Eigen::DenseCoeffsBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true> >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true> >’
# Eigen/src/Core/MapBase.h:27:34:   [ skipping 14 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/ReturnByValue.h:61:48:   required from ‘void Eigen::ReturnByValue<Derived>::evalTo(Dest&) const [with Dest = Eigen::Matrix<double, 3, 1>; Derived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:529:113:   required from ‘static Derived& Eigen::internal::assign_selector<Derived, OtherDerived, false, false>::evalTo(ActualDerived&, const ActualOtherDerived&) [with ActualDerived = Eigen::Matrix<double, 3, 1>; ActualOtherDerived = Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >; Derived = Eigen::Matrix<double, 3, 1>; OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:585:71:   required from ‘Derived& Eigen::MatrixBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/PlainObjectBase.h:421:29:   required from ‘Derived& Eigen::PlainObjectBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/Matrix.h:190:29:   required from ‘Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>& Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; _Scalar = double; int _Rows = 3; int _Cols = 1; int _Options = 0; int _MaxRows = 3; int _MaxCols = 1]’
# OMS.cc:133:37:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > >, 0>’:
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > >, double, double, Eigen::DenseCoeffsBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > >, 0>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >’
# Eigen/src/Core/CwiseUnaryOp.h:92:7:   required from ‘class Eigen::CwiseUnaryOpImpl<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> >, Eigen::Dense>’
# Eigen/src/Core/CwiseUnaryOp.h:59:7:   required from ‘class Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > >’
# Eigen/src/Core/GeneralProduct.h:235:45:   [ skipping 9 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/ReturnByValue.h:61:48:   required from ‘void Eigen::ReturnByValue<Derived>::evalTo(Dest&) const [with Dest = Eigen::Matrix<double, 3, 1>; Derived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:529:113:   required from ‘static Derived& Eigen::internal::assign_selector<Derived, OtherDerived, false, false>::evalTo(ActualDerived&, const ActualOtherDerived&) [with ActualDerived = Eigen::Matrix<double, 3, 1>; ActualOtherDerived = Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >; Derived = Eigen::Matrix<double, 3, 1>; OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:585:71:   required from ‘Derived& Eigen::MatrixBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/PlainObjectBase.h:421:29:   required from ‘Derived& Eigen::PlainObjectBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/Matrix.h:190:29:   required from ‘Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>& Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; _Scalar = double; int _Rows = 3; int _Cols = 1; int _Options = 0; int _MaxRows = 3; int _MaxCols = 1]’
# OMS.cc:133:37:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# Eigen/src/Core/DenseCoeffsBase.h: In instantiation of ‘class Eigen::DenseCoeffsBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >, 0>’:
# Eigen/src/Core/DenseCoeffsBase.h:274:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >, 1>’
# Eigen/src/Core/DenseCoeffsBase.h:636:7:   required from ‘class Eigen::DenseCoeffsBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >, 3>’
# Eigen/src/Core/util/XprHelper.h:371:8:   required from ‘struct Eigen::internal::special_scalar_op_base<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >, double, double, Eigen::DenseCoeffsBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > >, 3>, false>’
# Eigen/src/Core/DenseBase.h:41:34:   required from ‘class Eigen::DenseBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > > >’
# Eigen/src/Core/MatrixBase.h:48:34:   required from ‘class Eigen::MatrixBase<Eigen::SelfCwiseBinaryOp<Eigen::internal::scalar_difference_op<double>, Eigen::Block<Eigen::Block<Eigen::Block<Eigen::Matrix<double, 3, 1>, -1, 1, false>, -1, 1, false>, -1, 1, true>, Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::CwiseUnaryOp<Eigen::internal::scalar_multiple_op<double>, const Eigen::Block<const Eigen::Matrix<double, 3, 3>, -1, 1, false> > > > >’
# Eigen/src/Core/SelfCwiseBinaryOp.h:45:63:   [ skipping 12 instantiation contexts, use -ftemplate-backtrace-limit=0 to disable ]
# Eigen/src/Core/ReturnByValue.h:61:48:   required from ‘void Eigen::ReturnByValue<Derived>::evalTo(Dest&) const [with Dest = Eigen::Matrix<double, 3, 1>; Derived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:529:113:   required from ‘static Derived& Eigen::internal::assign_selector<Derived, OtherDerived, false, false>::evalTo(ActualDerived&, const ActualOtherDerived&) [with ActualDerived = Eigen::Matrix<double, 3, 1>; ActualOtherDerived = Eigen::ReturnByValue<Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> > >; Derived = Eigen::Matrix<double, 3, 1>; OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >]’
# Eigen/src/Core/Assign.h:585:71:   required from ‘Derived& Eigen::MatrixBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/PlainObjectBase.h:421:29:   required from ‘Derived& Eigen::PlainObjectBase<Derived>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; Derived = Eigen::Matrix<double, 3, 1>]’
# Eigen/src/Core/Matrix.h:190:29:   required from ‘Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>& Eigen::Matrix<_Scalar, _Rows, _Cols, _Options, _MaxRows, _MaxCols>::operator=(const Eigen::ReturnByValue<OtherDerived>&) [with OtherDerived = Eigen::internal::solve_retval_base<Eigen::ColPivHouseholderQR<Eigen::Matrix<double, 3, 3> >, Eigen::Matrix<double, 3, 1> >; _Scalar = double; int _Rows = 3; int _Cols = 1; int _Options = 0; int _MaxRows = 3; int _MaxCols = 1]’
# OMS.cc:133:37:   required from here
# Eigen/src/Core/DenseCoeffsBase.h:56:30: warning: ignoring attributes on template argument ‘Eigen::internal::packet_traits<double>::type’ {aka ‘__m128d’} [-Wignored-attributes]
# g++ -Ivoro++/src  -g  -c main.cc
#
# Linking network
# g++ -Ivoro++/src  -Lvoro++/src -o network -g  network.o networkinfo.o networkio.o instructions.o networkanalysis.o area_and_volume.o segment.o string_additions.o symbcalc.o ray.o graphstorage.o networkstorage.o voronoicell.o channel.o mindist.o feature.o v_network.o geometry.o holograms.o grid.o psd.o sphere_approx.o networkaccessibility.o poreinfo.o cluster.o net.o rmsd.o symmetry.o cycle.o arguments.o material.o OMS.o main.o -lvoro++
# g++ -Ivoro++/src  -g  -c framework_builder.cc
#
# Linking framework_builder
# g++ -Ivoro++/src  -Lvoro++/src -o framework_builder -g  network.o networkinfo.o networkio.o instructions.o networkanalysis.o area_and_volume.o segment.o string_additions.o symbcalc.o ray.o graphstorage.o networkstorage.o voronoicell.o channel.o mindist.o feature.o v_network.o geometry.o holograms.o grid.o psd.o sphere_approx.o networkaccessibility.o poreinfo.o cluster.o net.o rmsd.o symmetry.o cycle.o arguments.o material.o OMS.o framework_builder.o -lvoro++
# g++ -Ivoro++/src  -g  -c molecule_to_abstract.cc
#
# Linking molecule_to_abstract
# g++ -Ivoro++/src  -Lvoro++/src -o molecule_to_abstract -g  network.o networkinfo.o networkio.o instructions.o networkanalysis.o area_and_volume.o segment.o string_additions.o symbcalc.o ray.o graphstorage.o networkstorage.o voronoicell.o channel.o mindist.o feature.o v_network.o geometry.o holograms.o grid.o psd.o sphere_approx.o networkaccessibility.o poreinfo.o cluster.o net.o rmsd.o symmetry.o cycle.o arguments.o material.o OMS.o molecule_to_abstract.o -lvoro++

# %%
# !zeo++-0.3/network
# Out:
# Network commandline invocation syntax:
#
# ./network [-cssr [outputfile_cssr]]
#           [-cif  [outputfile_cif]]
#           [-v1   [outputfile_v1]]
#           [-xyz  [outputfile_xyz]]
#           [-superxyz  [outputfile_xyz]]
#           [-vtk  [outputfile_vtk]]
#           [-vis  [outputfile_vtk/xyz]]
#           [-nt2  [outputfile_nt2]]
#           [-mopac  [outputfile_mop]]
#           [-supermopac  [outputfile_mop]]
#           [-res  [outputfile_res]]
#           [-zvis [outputfile_zvis]]
#           [-axs probe_radius [outputfile_axs]]
#           [-sa chan_radius probe_radius num_samples [outputfile_sa]]
#           [-vol chan_radius probe_radius num_samples [outputfile_vol]]
#           [-volpo chan_radius probe_radius num_samples [outputfile_vol]]
#           [-psd chan_radius probe_radius num_samples [outputfile_sa]]
#           [-ray chan_radius probe_radius num_samples [outputfile_ray]]
#           [-chan probe_radius [outputfile_chan]]
#           [-visVoro probe_radius [unit_cell_shifts: a b c]]
#           [-sphericalSubstructures probe_radius sphere_radius [element_type]]
#           [-findTetrahedra element_type]
#           [-cellmulti sphere_radius]
#           [-r [radfile]]
#           [-nor ]
#           INPUTFILE
#
#
#  Note: For all of the program features that have an optional outputfile, the output is written to the filename when it is provided. Otherwise,
#  the output is  written to ($file_prefix).($feature_name). For instance, if the provided file is ABW.cuc and -cssr is specified w/o any output file,
#  the resulting input will be written by default to ABW.cssr
#
#  -cssr [outputfile_cssr] : Output a .cssr representation of the input file.
#
#  -cif  [outputfile_cif]  : Output a .cif representation of the input file.
#
#  -v1   [outputfile_v1]   : Output a .v1 representation of the input file.
#
#  -xyz  [outputfile_xyz]  : Output a .xyz representation of the input file.
#
#  -superxyz  [outputfile_xyz]  : Output a .xyz representation of a supercell of the input file.
#
#  -vtk  [outputfile_vtk]  : Output a .vtk representation of the unit cell of the input file.
#
#  -vis  [outputfile_vtk/xyz]  : For visualization: Output .xyz representations of the input file and a supercell of the input file, with duplicated perimeter atoms, and a .vtk representation of the unit cell of the input file.
#
#  -nt2  [outputfile_nt2]  : Output a .nt2 representation of the Voronoi network for the given unit cell.
#
#  -mopac  [outputfile_mop]  : Output a .mop representation of the input file.
#
#  -supermopac  [outputfile_mop]  : Output a .mop representation of a supercell of the input file.
#
#  -r    [radfile] : Use radii while performing the Vornoi decomposition (default behavior). If no .rad file is provided,
#                    default radii contained within the program are used, if possible. If a .rad
#                    file is provided, the default radii are overriden. The .rad file consists of
#                    two columns, containing the atomic types and radii respectively. For an example
#                    file, please refer to example.rad.
#  -nor             : Do not use radii while performing the Vornoi decomposition.
#
#  -mass massfile :  Replace the built-in mass table with that provided in a .mass file. The .mass file consists
#                    of two columns, containing the atomic types and masses respectively. For an example file,
#                    please refer to example.mass
#
#  -res  [outputfile_res] : Output the maximum free sphere results to the provided file.
#                           Format is: maxIncDiam maxDiam incDiam
#                           where  maxIncDiam is the maximum included sphere diamter, maxDiam is the maximum free sphere diameter
# 	                    and incDiam is the maximum included diameters for the maximum free sphere path.
#
#  -resex  [outputfile_res] : Extended -res printout. Additionally prints free and included sphere along each of a,b, and c axis
#
#  -zvis [outputfile_zvis] : Output a file used by ZeoVis to depict important features about the atomic network and Voronoi network.
#
#  -axs probe_radius [outputfile_axs] : Outputs a file with N lines, where N = # of Voronoi nodes.
# 	  		              Each line is true or false, representing the accessibility of the ith Voronoi node.
#
#  -sa chan_radius probe_radius num_samples_per_atom  [outputfile_sa]  : Determine the amount of accessible surface area. The accessibility of nodes is determined
#                                    	                               using $chan_radius, and probe-atom overlap is determiend using $probe_radius. A total of
# 	                                                               $num_samples_per_atom points are sampled at a distance of $probe_radius from the atoms and Monte
# 	                                                               Carlo integration is used to determine the final result.
#
#  -vol chan_radius probe_radius num_samples_total [outputfile_vol]  : Determine the amount of accessible volume. The accessibility of nodes is determined
#                                                                     using $chan_radius, and probe-atom overlap is determined using $probe_radius. A total of
# 	                                                            $num_samples_total points are sampled across the unit cell and Monte Carlo integration is used
# 	                                                            to determine the final result.
#
#  -volpo chan_radius probe_radius num_samples_total [outputfile_vol]  : Similar to -vol command but return probe-occupiable values.
#
#  -psd chan_radius probe_radius num_samples_total [outputfile_psd]  : Calculate pore size distribution histogram. The accessibility of nodes is determined
#                                                                     using $chan_radius, and probe-atom overlap is determined using $probe_radius. A total of
#                                                                   $num_samples_total points are sampled across the unit cell and Monte Carlo integration is used
#                                                                   to determine the final result.
#
#  -block probe_radius num_samples_total                       : Calculate blocking spheres to be used in MC simluations. The accessibility of nodes is determined
#                                                                    using $probe_radius. A total of $num_samples_total points are sampled across
#                                                                    the unit cell and Monte Carlo integration is used to determine the final result.
#
#  -ray_atom or -zray_atom chan_radius probe_radius num_samples_total [outputfile_ray] :
#  Shoot lines through accesible volume of cell until hits an atom and returns outputfile.r_atom with histogram of ray lengths (can be manipulated in source) also full information of ray lengths can be output in a file Ray_Info.txt in source
#
#  -ray_sphere or -zray_sphere chan_radius probe_radius num_samples_total [outputfile_ray] :
#  Shoot lines through voronoi nodes until it reaches a point outside of vornode and returns outputfile.r_atom with hitsogram of ray lengths (can be manipulated in source) also full information of ray lengths can be output in a file Ray_Info.txt in source
#
#  -ray_andrew_sphere or -zray_andrew_sphere chan_radius probe_radius num_samples_total [outputfile_ray] :
#  Randomly picks a point within the unitcell and shoots a ray until it reaches MAXRAYDIST and returns outputfile.r_atom with hitsogram of ray segments within vornodes (can be manipulated in source) also full information of ray lengths can be output in a file Ray_Info.txt in source
#
#  -ray_andrew_atom or -zray_andrew_atom chan_radius probe_radius num_samples_total [outputfile_ray] :
#  Randomly picks a point within the unitcell and shoots a ray until it reaches MAXRAYDIST and returns outputfile.r_atom with hitsogram of ray sements within accessible volume (can be manipulated in source) also full information of ray lengths can be output in a file Ray_Info.txt in source
#
#  -sub [outputfile_sub] : Attempt to replace every other Si atom within the network with an Al atom consistently.
#                          If successful, write the resulting network to a .cssr file. No output is written if the substitution fails.
#
#  -fsub frac [outputfile_fsub] : Attempt to randomly replace $frac of Si atoms within the network with an Al atom consistently. The specified fraction
#                                 must not exceed 0.5. If successful, write the resulting network to a .cssr file. No output is written if the substitution fails.
#
#  -fsubM frac seed [outputfile_fsub] : Attempt to randomly replace $frac of Si atoms within the network with Al atoms. The specified fraction
#                                 must not exceed 0.5. Random seed specified by seed (use 0 fo default). If successful, write the resulting network to a .cssr file.
#                                 This function uses different algorithms than -sub and -fsub, and may have problems reaching high $frac (email authors for more details). No output is written if the substitution fails.
#
#  -gridBOV : Write distance grid in BOV format (inputfilename_f.bov).
#  -gridG  : Write distance grid in Gaussian cube format (inputfilename.cube).
#  -gridGBohr  : Write distance grid in Gaussian cube format, with distances converted from Angstrom to Bohr (inputfilename.cube).
#  -chan probe_radius [outputfile_chan] : Determine the channels available to a probe of size $probe_radius.
#  -visVoro probe_radius [unit_cell_shifts: a b c] : For visualization: draw the Voronoi network as xyz and vtk formats, including only the accessible portion, which can be drawn in an adjacent unit cell with the provided shifts.
#  -sphericalSubstructures probe_radius sphere_radius [element_type] : For zeolites: Write out a number of xyz format files containing spherical substructures of the given radius, centred on given probe-accessible Voronoi nodes; if an element_type is given, a simplified Voronoi network is used, based only on atoms of that type.
#  -findTetrahedra element_type: Write to terminal the tetrahedrality (distortion) index for each tetrahedral arrangement of the specified atom type in the material
#  -cellmulti sphere_radius: Write to terminal the number of cells required in each crystallographic axis in order to construct a supercell, where a sphere with the provided radius will not overlap with itself periodically
# 		                        Outputs a file used by ZeoVis to draw the resulting channels.
#
#  INPUTFILE    : Must be in the .cssr, .cif, .cuc, .car, .arc or .v1 file format.

# %% [markdown]
# # Retricular material generation

# %% [markdown]
# ## Our Reward function
# It depends on both Gravimetric (GSA) and Volumetric (VA) surface areas

# %% [markdown]
# ### Reward function uses zeo++ : validating zeo++ works

# %%
mof = builder.make_pormake_mof(sequence)
mof.write_cif("test.cif")
# !zeo++-0.3/network -sa 1.525 1.525 2000 test.cif > test.sa
# !zeo++-0.3/network -vol 1.525 1.525 2000 test.cif > test.vol
# Out:
# /usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)

# %%
# !ls -l test.*
# Out:
# -rw-r--r-- 1 root root 18663 May 11 10:07 test.cif
# -rw-r--r-- 1 root root  1212 May 11 10:07 test.sa
# -rw-r--r-- 1 root root  1213 May 11 10:07 test.vol

# %%
#@title Create reward using Zeo++
# both GSA (Gravimetric) and VSA (Volume) surface area
# probe radius of 1.525 Å (CO2 length is 3.5Å) and 2000 samples
class SurfaceAreaRewarder():
    def __init__(self, builder,
                 gsa_cutoff, vsa_cutoff,
                 temporary_dir = "scratch"):
        self.builder = builder
        self.gsa_cutoff = gsa_cutoff
        self.vsa_cutoff = vsa_cutoff
        self.temporary_dir = temporary_dir
        os.makedirs(temporary_dir, exist_ok=True)

    def reward(self, sequence):
        '''
        Gravimetric surface area is ASA (accessible area) + NASA
        Volume surface area is AV (accessible volume) + NAV
        '''
        with tempfile.NamedTemporaryFile(suffix=".cif", dir=self.temporary_dir, delete=True) as temp:
            mof = builder.make_pormake_mof(sequence)
            mof.write_cif(temp.name)

            command_1=(['./zeo++-0.3/network']  + ['-sa'] + ['1.525'] + ['1.525'] + ['2000'] + [temp.name])
            subprocess.run(command_1,stdout = subprocess.DEVNULL)
            command_2=(['./zeo++-0.3/network']  + ['-vol'] + ['1.525'] + ['1.525'] + ['2000'] + [temp.name])
            subprocess.run(command_2,stdout = subprocess.DEVNULL)
            output_sa = temp.name.removesuffix(".cif") + ".sa"
            output_vol = temp.name.removesuffix(".cif") + ".vol"

            def genric_reward(output_filename):
              output_reward = 0
              if os.path.exists(output_filename) == False:
                  return output_reward
              # else calculate
              with open(output_filename) as result_file:
                  lines=[]
                  for line in result_file:
                      lines.append(line.rstrip())
                  # Zeo++ writes empty output file for some non-physical MOFs. Reward them as 0.
                  if len(lines)==0:
                      output_reward = 0
                  else:
                      frags=lines[0].split()
                      NASA_or_NAV=float(frags[17])
                      ASA_or_AV=float(frags[11])
                      # Gravimetric_or_Volume surface area is NASA_or_NAV + ASA_or_AV
                      output_reward = ASA_or_AV + NASA_or_NAV
                      #output_reward = math.exp((total_GSA_or_VSA - gsa_or_vsa_cutoff) / gsa_or_vsa_cutoff)
                  # Remove zeo++ output file
                  # Temp file will be removed by the surrounding "with"
                  os.remove(output_filename)
              return output_reward
            # calculate
            total_cost_GSA_plus_VSA = genric_reward(output_sa) + genric_reward(output_vol)
            cutoff = self.gsa_cutoff + self.vsa_cutoff
            output_reward = math.exp((total_cost_GSA_plus_VSA - cutoff) / cutoff)
            # step function
            output_reward = output_reward if output_reward > 0 else 0
            return output_reward

# %%
rewarder = SurfaceAreaRewarder(builder,
                               gsa_cutoff = 5000, vsa_cutoff= 2,
                               temporary_dir = "scratch")

# %% [markdown]
# ### Test reward function

# %%
sequence = builder.random_sequence()
print(sequence, rewarder.reward(sequence))
# Out:
# /usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# ['N387', 'N355', 'N519', 'E86', 'E114'] 1.2813204317895999

# %%
env = SequenceEnvironment(
    token_vocabulary = builder.token_vocabulary,
    termination_token = builder.termination_token,
    reward_function = lambda s: rewarder.reward(s),
    render_function = None,
    mask = builder.mask,
    max_sequence_length = builder.n_slots, min_sequence_length = builder.n_slots
    )

flow_model = LSTM(token_vocabulary = builder.token_vocabulary, n_actions = env.action_space.n)
agent = TrajectoryBalanceGFlowNet(env, flow_model)

# %% [markdown]
# ### train
# #### learning rate of $5 × 10^3$
# #### For demo : episodes = 1000

# %%
agent.train(True)
observations, infos, rewards, losses, logZs = agent.fit(learning_rate=5e-3, num_episodes=1000, minibatch_size=5)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#   0%|          | 1/1000 [00:03<51:38,  3.10s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#   0%|          | 2/1000 [00:05<44:13,  2.66s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#   0%|          | 3/1000 [00:08<46:38,  2.81s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#   0%|          | 4/1000 [00:10<43:42,  2.63s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2480.667, 1.0350009202957153:   0%|          | 5/1000 [00:13<45:14,  2.73s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2480.667, 1.0350009202957153:   1%|          | 6/1000 [00:15<40:23,  2.44s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2480.667, 1.0350009202957153:   1%|          | 7/1000 [00:18<40:45,  2.46s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2480.667, 1.0350009202957153:   1%|          | 8/1000 [00:20<42:24,  2.57s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2480.667, 1.0350009202957153:   1%|          | 9/1000 [00:24<46:02,  2.79s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2447.001, 1.0400009155273438:   1%|          | 10/1000 [00:26<44:17,  2.68s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2447.001, 1.0400009155273438:   1%|          | 11/1000 [00:29<46:50,  2.84s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2447.001, 1.0400009155273438:   1%|          | 12/1000 [00:32<47:12,  2.87s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2447.001, 1.0400009155273438:   1%|▏         | 13/1000 [00:35<47:32,  2.89s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2447.001, 1.0400009155273438:   1%|▏         | 14/1000 [00:37<44:20,  2.70s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2598.791, 1.0449999570846558:   2%|▏         | 15/1000 [00:39<40:18,  2.46s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2598.791, 1.0449999570846558:   2%|▏         | 16/1000 [00:42<39:21,  2.40s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2598.791, 1.0449999570846558:   2%|▏         | 17/1000 [00:44<38:24,  2.34s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2598.791, 1.0449999570846558:   2%|▏         | 18/1000 [00:48<48:11,  2.94s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2598.791, 1.0449999570846558:   2%|▏         | 19/1000 [00:50<41:37,  2.55s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2460.954, 1.0500037670135498:   2%|▏         | 20/1000 [00:52<41:42,  2.55s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2460.954, 1.0500037670135498:   2%|▏         | 21/1000 [00:55<44:24,  2.72s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2460.954, 1.0500037670135498:   2%|▏         | 22/1000 [00:58<41:21,  2.54s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2460.954, 1.0500037670135498:   2%|▏         | 23/1000 [01:01<46:23,  2.85s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2460.954, 1.0500037670135498:   2%|▏         | 24/1000 [01:03<40:30,  2.49s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2454.319, 1.0550044775009155:   2%|▎         | 25/1000 [01:05<41:26,  2.55s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2454.319, 1.0550044775009155:   3%|▎         | 26/1000 [01:07<35:43,  2.20s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2454.319, 1.0550044775009155:   3%|▎         | 27/1000 [01:10<40:06,  2.47s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2454
/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2307.744, 2.004648447036743:  99%|█████████▉| 989/1000 [44:27<00:28,  2.58s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2254.307, 2.009561538696289:  99%|█████████▉| 990/1000 [44:29<00:23,  2.37s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2254.307, 2.009561538696289:  99%|█████████▉| 991/1000 [44:32<00:22,  2.54s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2254.307, 2.009561538696289:  99%|█████████▉| 992/1000 [44:34<00:19,  2.42s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2254.307, 2.009561538696289:  99%|█████████▉| 993/1000 [44:39<00:22,  3.19s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2254.307, 2.009561538696289:  99%|█████████▉| 994/1000 [44:42<00:18,  3.07s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2389.619, 2.0144715309143066: 100%|█████████▉| 995/1000 [44:44<00:13,  2.78s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2389.619, 2.0144715309143066: 100%|█████████▉| 996/1000 [44:47<00:10,  2.73s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2389.619, 2.0144715309143066: 100%|█████████▉| 997/1000 [44:50<00:08,  2.97s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2389.619, 2.0144715309143066: 100%|█████████▉| 998/1000 [44:52<00:05,  2.55s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2389.619, 2.0144715309143066: 100%|█████████▉| 999/1000 [44:54<00:02,  2.45s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 2339.556, 2.0193920135498047: 100%|██████████| 1000/1000 [44:57<00:00,  2.70s/it]

# %% [markdown]
# ## Generate 10 observations

# %%
agent.eval()
trained_observations = []

for i in tqdm(range(0, 10)):
    obs, info, reward, _ = agent.sample()
    sequence = agent.env._sequence[:-1]
    trained_observations.append([sequence, 0 if reward == 0 else math.log(reward) * cutoff + cutoff])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  10%|█         | 1/10 [00:04<00:43,  4.81s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  20%|██        | 2/10 [00:11<00:49,  6.19s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  30%|███       | 3/10 [00:16<00:37,  5.34s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  40%|████      | 4/10 [00:20<00:28,  4.79s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  50%|█████     | 5/10 [00:23<00:20,  4.18s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  60%|██████    | 6/10 [00:26<00:15,  3.79s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  70%|███████   | 7/10 [00:29<00:10,  3.51s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  80%|████████  | 8/10 [00:31<00:06,  3.06s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
#  90%|█████████ | 9/10 [00:34<00:03,  3.01s/it]/usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# 100%|██████████| 10/10 [00:36<00:00,  3.68s/it]

# %%
trained_observations
# Out:
# [[['N288', 'N424', 'N19', 'E32', 'E148'], 8111.821171531388],
#  [['N263', 'N549', 'N353', 'E170', 'E84'], 6048.799540183927],
#  [['N387', 'N718', 'N137', 'E166', 'E92'], 4679.079528188725],
#  [['N524', 'N631', 'N535', 'E3', 'E3'], 8027.998600559777],
#  [['N128', 'N551', 'N333', 'E104', 'E89'], 5900.448120751698],
#  [['N603', 'N207', 'N410', 'E118', 'E139'], 5581.801879248301],
#  [['N44', 'N302', 'N80', 'E199', 'E110'], 6910.134746101559],
#  [['N335', 'N153', 'N495', 'E11', 'E230'], 4812.632217113155],
#  [['N42', 'N257', 'N579', 'E16', 'E102'], 3988.046181527389],
#  [['N688', 'N128', 'N353', 'E222', 'E89'], 4715.671091563375]]

# %%
structure =  builder.make_structure(trained_observations[0][0])

# Visualise it with Pymatgen
nv.show_pymatgen(structure)
# Out:
# /usr/local/lib/python3.11/dist-packages/pormake/locator.py:20: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   U, rmsd = scipy.spatial.transform.Rotation.align_vectors(p, q)
# NGLWidget()
